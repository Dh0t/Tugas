# %% [markdown]
# <a href="https://colab.research.google.com/github/Dh0t/Tugas/blob/main/Tuags_NLP_PTM11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import random
import string

# Persiapan Data

input_texts = [
    "satu", "dua", "tiga", "empat", "lima",
    "satu dua", "dua tiga", "tiga empat", "empat lima",
    "satu dua tiga", "dua tiga empat", "tiga empat lima"
]

target_texts = [
    "01", "10", "11", "001", "010",
    "0110", "1011", "11001", "001010",
    "011011", "1011001", "11001010"
]

# Target sequence
target_texts_input = ['\t' + text for text in target_texts] # Input decoder
target_texts_output = [text + '\n' for text in target_texts] # Output decoder

# Karakter unik untuk input dan target
input_characters = sorted(list(set(' '.join(input_texts))))
target_characters = sorted(list(set(''.join(target_texts_input + target_texts_output))))

num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)

max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts]) + 2

print(f"Jumlah sampel: {len(input_texts)}")
print(f"Karakter unik encoder: {num_encoder_tokens}")
print(f"Karakter unik decoder: {num_decoder_tokens}")
print(f"Panjang sequence encoder maksimum: {max_encoder_seq_length}")
print(f"Panjang sequence decoder maksimum: {max_decoder_seq_length}")

# Untuk mapping karakter ke indeks integer
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

# Inisialisasi array untuk data input, target input, dan target output (one-hot encoding)
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32'
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32'
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32'
)

# Isi array dengan data one-hot
for i, (input_text, target_text_input, target_text_output) in enumerate(zip(input_texts, target_texts_input, target_texts_output)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text_input):
        decoder_input_data[i, t, target_token_index[char]] = 1.
    for t, char in enumerate(target_text_output):
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# Membangun Model Seq2Seq (Encoder-Decoder)

# Encoder
encoder_inputs = tf.keras.Input(shape=(None, num_encoder_tokens))
encoder_lstm = tf.keras.layers.LSTM(256, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = tf.keras.Input(shape=(None, num_decoder_tokens))
decoder_lstm = tf.keras.layers.LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = tf.keras.layers.Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Definisi model
model = tf.keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Kompilasi model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Ringkasan model
model.summary()

# Pelatihan Model
batch_size = 64
epochs = 100

print("\nMulai pelatihan model...")
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
print("Pelatihan selesai.")

# Inferensi (Prediksi) Model

# Encoder Inferensi: Mengambil input dan menghasilkan state
encoder_model = tf.keras.Model(encoder_inputs, encoder_states)

# Decoder Inferensi: Mengambil state awal dan input token saat ini
decoder_state_input_h = tf.keras.Input(shape=(256,))
decoder_state_input_c = tf.keras.Input(shape=(256,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = tf.keras.Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Fungsi untuk melakukan decoding (menerjemahkan)
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Loop untuk menghasilkan karakter demi karakter
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Ambil token dengan probabilitas tertinggi
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Kondisi berhenti: jika mencapai token akhir atau panjang maksimum
        if (sampled_char == '\n' or
                len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update target sequence (input untuk langkah berikutnya)
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

print("\n--- Hasil Prediksi ---")
for seq_index in range(len(input_texts)):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print(f"Input: {input_texts[seq_index]}")
    print(f"Target: {target_texts[seq_index]}")
    print(f"Prediksi: {decoded_sentence.strip()}")
    print("-" * 10)
# Out:
# Jumlah sampel: 12
# Karakter unik encoder: 12
# Karakter unik decoder: 4
# Panjang sequence encoder maksimum: 15
# Panjang sequence decoder maksimum: 10
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_34      │ (None, None, 12)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_35      │ (None, None, 4)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_22 (LSTM)      │ [(None, 256),     │    275,456 │ input_layer_34[0… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_23 (LSTM)      │ [(None, None,     │    267,264 │ input_layer_35[0… │
# │                     │ 256), (None,      │            │ lstm_22[0][1],    │
# │                     │ 256), (None,      │            │ lstm_22[0][2]     │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, None, 4)   │      1,028 │ lstm_23[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 543,748 (2.07 MB)
#  Trainable params: 543,748 (2.07 MB)
#  Non-trainable params: 0 (0.00 B)
# Mulai pelatihan model...
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4333 - loss: 0.4795 - val_accuracy: 0.3667 - val_loss: 0.9622
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step - accuracy: 0.1556 - loss: 0.4740 - val_accuracy: 0.3333 - val_loss: 0.9539
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.1444 - loss: 0.4703 - val_accuracy: 0.3333 - val_loss: 0.9452
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.1333 - loss: 0.4668 - val_accuracy: 0.3333 - val_loss: 0.9331
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.1333 - loss: 0.4624 - val_accuracy: 0.3333 - val_loss: 0.9068
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.1333 - loss: 0.4527 - val_accuracy: 0.3333 - val_loss: 0.8288
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.1333 - loss: 0.4203 - val_accuracy: 0.3667 - val_loss: 0.7575
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.1333 - loss: 0.3819 - val_accuracy: 0.3333 - val_loss: 0.7906
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.1556 - loss: 0.3769 - val_accuracy: 0.3000 - val_loss: 0.7802
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.1667 - loss: 0.3703 - val_accuracy: 0.3000 - val_loss: 0.7933
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.1667 - loss: 0.3726 - val_accuracy: 0.2667 - val_loss: 0.7996
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.1556 - loss: 0.3694 - val_accuracy: 0.2667 - val_loss: 0.7954
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.1556 - loss: 0.3710 - val_accuracy: 0.2667 - val_loss: 0.8023
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.1667 - loss: 0.3679 - val_accuracy: 0.2667 - val_loss: 0.7966
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.1556 - loss: 0.3685 - val_accuracy: 0.2667 - val_loss: 0.7993
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.1556 - loss: 0.3673 - val_accuracy: 0.2667 - val_loss: 0.7990
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.1556 - loss: 0.3668 - val_accuracy: 0.2667 - val_loss: 0.7998
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.1556 - loss: 0.3662 - val_accuracy: 0.2667 - val_loss: 0.7998
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.1667 - loss: 0.3659 - val_accuracy: 0.2667 - val_loss: 0.8000
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3656 - val_accuracy: 0.2667 - val_loss: 0.8001
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.1667 - loss: 0.3654 - val_accuracy: 0.2667 - val_loss: 0.8003
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1667 - loss: 0.3651 - val_accuracy: 0.2667 - val_loss: 0.8005
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.1667 - loss: 0.3649 - val_accuracy: 0.2667 - val_loss: 0.8007
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.1778 - loss: 0.3647 - val_accuracy: 0.2667 - val_loss: 0.8009
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.1778 - loss: 0.3645 - val_accuracy: 0.2667 - val_loss: 0.8010
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.1667 - loss: 0.3643 - val_accuracy: 0.2667 - val_loss: 0.8011
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.1667 - loss: 0.3641 - val_accuracy: 0.2333 - val_loss: 0.8011
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.1667 - loss: 0.3639 - val_accuracy: 0.2333 - val_loss: 0.8012
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.1667 - loss: 0.3637 - val_accuracy: 0.2333 - val_loss: 0.8012
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.1667 - loss: 0.3635 - val_accuracy: 0.2333 - val_loss: 0.8013
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.1667 - loss: 0.3633 - val_accuracy: 0.2333 - val_loss: 0.8013
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.1667 - loss: 0.3632 - val_accuracy: 0.2333 - val_loss: 0.8013
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.1667 - loss: 0.3630 - val_accuracy: 0.2333 - val_loss: 0.8014
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step - accuracy: 0.1667 - loss: 0.3629 - val_accuracy: 0.2333 - val_loss: 0.8014
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.1667 - loss: 0.3628 - val_accuracy: 0.2333 - val_loss: 0.8014
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.1667 - loss: 0.3627 - val_accuracy: 0.2333 - val_loss: 0.8014
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.1667 - loss: 0.3626 - val_accuracy: 0.2333 - val_loss: 0.8014
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.1667 - loss: 0.3625 - val_accuracy: 0.2333 - val_loss: 0.8014
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.1667 - loss: 0.3624 - val_accuracy: 0.2333 - val_loss: 0.8013
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.1667 - loss: 0.3623 - val_accuracy: 0.2333 - val_loss: 0.8013
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.1667 - loss: 0.3623 - val_accuracy: 0.2333 - val_loss: 0.8012
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.1667 - loss: 0.3622 - val_accuracy: 0.2333 - val_loss: 0.8012
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.1667 - loss: 0.3621 - val_accuracy: 0.2333 - val_loss: 0.8011
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.1667 - loss: 0.3620 - val_accuracy: 0.2333 - val_loss: 0.8010
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.1667 - loss: 0.3619 - val_accuracy: 0.2333 - val_loss: 0.8008
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3618 - val_accuracy: 0.2333 - val_loss: 0.8007
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.1667 - loss: 0.3617 - val_accuracy: 0.2333 - val_loss: 0.8005
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.1667 - loss: 0.3616 - val_accuracy: 0.2333 - val_loss: 0.8003
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.1667 - loss: 0.3615 - val_accuracy: 0.2333 - val_loss: 0.8001
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.1667 - loss: 0.3613 - val_accuracy: 0.2333 - val_loss: 0.7999
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.1667 - loss: 0.3612 - val_accuracy: 0.2333 - val_loss: 0.7995
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.1667 - loss: 0.3610 - val_accuracy: 0.2333 - val_loss: 0.7996
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.1667 - loss: 0.3609 - val_accuracy: 0.2333 - val_loss: 0.7981
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.1667 - loss: 0.3606 - val_accuracy: 0.2333 - val_loss: 0.8021
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.1667 - loss: 0.3610 - val_accuracy: 0.2667 - val_loss: 0.7855
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.1556 - loss: 0.3599 - val_accuracy: 0.2333 - val_loss: 0.8269
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.1667 - loss: 0.3696 - val_accuracy: 0.2667 - val_loss: 0.7822
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.1556 - loss: 0.3597 - val_accuracy: 0.2333 - val_loss: 0.8178
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.1667 - loss: 0.3662 - val_accuracy: 0.2667 - val_loss: 0.7888
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.1556 - loss: 0.3594 - val_accuracy: 0.2333 - val_loss: 0.8056
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.1667 - loss: 0.3615 - val_accuracy: 0.2667 - val_loss: 0.7899
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.1556 - loss: 0.3587 - val_accuracy: 0.2333 - val_loss: 0.8054
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.1667 - loss: 0.3610 - val_accuracy: 0.2667 - val_loss: 0.7868
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.1556 - loss: 0.3580 - val_accuracy: 0.2333 - val_loss: 0.8102
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.1667 - loss: 0.3620 - val_accuracy: 0.2667 - val_loss: 0.7810
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.1556 - loss: 0.3575 - val_accuracy: 0.2333 - val_loss: 0.8175
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.1667 - loss: 0.3647 - val_accuracy: 0.2667 - val_loss: 0.7803
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.1556 - loss: 0.3570 - val_accuracy: 0.2333 - val_loss: 0.8140
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.1667 - loss: 0.3631 - val_accuracy: 0.2667 - val_loss: 0.7806
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.1556 - loss: 0.3562 - val_accuracy: 0.2333 - val_loss: 0.8116
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.1667 - loss: 0.3617 - val_accuracy: 0.2667 - val_loss: 0.7786
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1556 - loss: 0.3554 - val_accuracy: 0.2333 - val_loss: 0.8135
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3621 - val_accuracy: 0.2667 - val_loss: 0.7760
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.1556 - loss: 0.3549 - val_accuracy: 0.2333 - val_loss: 0.8154
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.1667 - loss: 0.3627 - val_accuracy: 0.2667 - val_loss: 0.7752
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.1556 - loss: 0.3542 - val_accuracy: 0.2333 - val_loss: 0.8140
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.1667 - loss: 0.3617 - val_accuracy: 0.2667 - val_loss: 0.7745
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.1556 - loss: 0.3534 - val_accuracy: 0.2333 - val_loss: 0.8130
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.1667 - loss: 0.3607 - val_accuracy: 0.2667 - val_loss: 0.7730
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.1556 - loss: 0.3527 - val_accuracy: 0.2333 - val_loss: 0.8137
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3607 - val_accuracy: 0.2667 - val_loss: 0.7718
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.1556 - loss: 0.3520 - val_accuracy: 0.2333 - val_loss: 0.8136
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.1667 - loss: 0.3603 - val_accuracy: 0.2667 - val_loss: 0.7712
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.1556 - loss: 0.3513 - val_accuracy: 0.2333 - val_loss: 0.8124
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.1667 - loss: 0.3593 - val_accuracy: 0.2667 - val_loss: 0.7702
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.1556 - loss: 0.3505 - val_accuracy: 0.2333 - val_loss: 0.8120
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.1667 - loss: 0.3587 - val_accuracy: 0.2667 - val_loss: 0.7689
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.1556 - loss: 0.3498 - val_accuracy: 0.2333 - val_loss: 0.8120
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.1667 - loss: 0.3584 - val_accuracy: 0.2667 - val_loss: 0.7680
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.1667 - loss: 0.3491 - val_accuracy: 0.2333 - val_loss: 0.8112
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.1667 - loss: 0.3576 - val_accuracy: 0.2667 - val_loss: 0.7673
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.1667 - loss: 0.3483 - val_accuracy: 0.2333 - val_loss: 0.8101
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3567 - val_accuracy: 0.2667 - val_loss: 0.7662
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.1667 - loss: 0.3475 - val_accuracy: 0.2333 - val_loss: 0.8097
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.1667 - loss: 0.3562 - val_accuracy: 0.2667 - val_loss: 0.7650
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.1667 - loss: 0.3468 - val_accuracy: 0.2333 - val_loss: 0.8091
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.1667 - loss: 0.3557 - val_accuracy: 0.2667 - val_loss: 0.7642
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3461 - val_accuracy: 0.2333 - val_loss: 0.8080
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.1667 - loss: 0.3549 - val_accuracy: 0.2667 - val_loss: 0.7632
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1667 - loss: 0.3453 - val_accuracy: 0.2333 - val_loss: 0.8070
# Pelatihan selesai.
#
# --- Hasil Prediksi ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Input: satu
# Target: 01
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Input: dua
# Target: 10
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Input: tiga
# Target: 11
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Input: empat
# Target: 001
# Prediksi: 111
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Input: lima
# Target: 010
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Input: satu dua
# Target: 0110
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Input: dua tiga
# Target: 1011
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Input: tiga empat
# Target: 11001
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Input: empat lima
# Target: 001010
# Prediksi: 111
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Input: satu dua tiga
# Target: 011011
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Input: dua tiga empat
# Target: 1011001
# Prediksi: 11
# ----------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Input: tiga empat lima
# Target: 11001010
# Prediksi: 11
# ----------
